# %%
# Importar librerías
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve

# %%
# Cargar la segunda hoja del archivo Excel
data = pd.read_excel("/Users/berlinbelavi/Desktop/proyecto_final/Heart_Disease_Prediction.xlsx", sheet_name=1)

# Imprime la forma del DataFrame
print(data.shape)
# Out:
# (270, 15)

# %%
data.head()
# Out:
#    age  sex  chest_pain_type   bp  cholesterol  fbs_over_120  ekg_results  \
# 0   70    1                4  130          322             0            2
# 1   67    0                3  115          564             0            2
# 2   57    1                2  124          261             0            0
# 3   64    1                4  128          263             0            0
# 4   74    0                2  120          269             0            2
#
#    max_hr  excercise_angina  st_depression  slope_of_st  number_vessels  \
# 0     109                 0             24            2               3
# 1     160                 0             16            2               0
# 2     141                 0              3            1               0
# 3     105                 1              2            2               1
# 4     121                 1              2            1               1
#
#    thallium heart_disease  hd_dummy
# 0         3      Presence         1
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   age               270 non-null    int64
#  1   sex               270 non-null    int64
#  2   chest_pain_type   270 non-null    int64
#  3   bp                270 non-null    int64
#  4   cholesterol       270 non-null    int64
#  5   fbs_over_120      270 non-null    int64
#  6   ekg_results       270 non-null    int64
#  7   max_hr            270 non-null    int64
#  8   excercise_angina  270 non-null    int64
#  9   st_depression     270 non-null    int64
#  10  slope_of_st       270 non-null    int64
#  11  number_vessels    270 non-null    int64
#  12  thallium          270 non-null    int64
#  13  heart_disease     270 non-null    object
#  14  hd_dummy          270 non-null    int64
# dtypes: int64(14), object(1)
# memory usage: 31.8+ KB

# %% [markdown]
# no es necesario hacer la imputacion de los datos ya que los datos son iguales en cada columna

# %% [markdown]
# Distribucion de variables numericas

# %%
numerical_columns = ['age', 'bp', 'cholesterol', 'max_hr', 'st_depression']
for col in numerical_columns:
    sns.histplot(data[col], kde=True)
    plt.title(f'Distribución de {col}')
    plt.show()

# %% [markdown]
# analisis de frecuencia para variables categoricas

# %%
categorical_columns = ['sex', 'chest_pain_type', 'thallium', 'heart_disease']
for col in categorical_columns:
    sns.countplot(x=data[col])
    plt.title(f'Frecuencia de {col}')
    plt.show()

# %% [markdown]
# Correlación entre Variables

# %%
# Convertir 'heart_disease' de valores categóricos a numéricos
data['heart_disease'] = data['heart_disease'].map({'Presence': 1, 'Absence': 0})

# Verificar que la conversión fue exitosa
print(data['heart_disease'].head())

# Seleccionar solo columnas numéricas para la correlación
numeric_data = data.select_dtypes(include=['int64', 'float64'])

# Calcular la matriz de correlación
correlation_matrix = numeric_data.corr()

# Visualizar la matriz de correlación
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Matriz de correlación')
plt.show()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    0
# Name: heart_disease, dtype: int64

# %% [markdown]
# Relación de Variables con la Enfermedad Cardiaca

# %%
sns.boxplot(x='heart_disease', y='age', data=data)
plt.title('Relación entre Edad y Enfermedad Cardíaca')
plt.show()

sns.barplot(x='heart_disease', y='cholesterol', data=data)
plt.title('Relación entre Colesterol y Enfermedad Cardíaca')
plt.show()

# %% [markdown]
# Identificación de Valores Atípicos

# %%
for col in numerical_columns:
    sns.boxplot(x=data[col])
    plt.title(f'Detección de valores atípicos en {col}')
    plt.show()

# %% [markdown]
# Distribución de la Edad por Sexo

# %%
sns.histplot(data=data, x='age', hue='sex', kde=True, palette='pastel')
plt.title('Distribución de Edad por Sexo')
plt.show()

# %%
#Análisis Multivariable

# %%
sns.scatterplot(x='max_hr', y='cholesterol', hue='heart_disease', style='sex', data=data)
plt.title('Relación entre Max HR, Colesterol y Enfermedad Cardíaca')
plt.show()

# %%
print(data.isnull().sum())
# Out:
# age                 0
# sex                 0
# chest_pain_type     0
# bp                  0
# cholesterol         0
# fbs_over_120        0
# ekg_results         0
# max_hr              0
# excercise_angina    0
# st_depression       0
# slope_of_st         0
# number_vessels      0
# thallium            0
# heart_disease       0
# hd_dummy            0
# dtype: int64

# %%
#Convertir variables categóricas a variables dummy
data = pd.get_dummies(data, columns=['chest_pain_type', 'thallium'], drop_first=True)

# %%
#Separar variables independientes (X) y dependiente (y)
X = data.drop(columns=['heart_disease', 'hd_dummy'])  # Eliminar la variable objetivo
y = data['hd_dummy']

# %%
#Escalar las variables numéricas 
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
#Dividir los datos en entrenamiento y prueba Divide los datos escalados:
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
#Entrenar un modelo de clasificación (Regresion logistica)
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(random_state=42)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=42)

# %%
#Evaluar el modelo Predicciones, matriz de confusión y métricas:
from sklearn.metrics import classification_report, confusion_matrix

y_pred = model.predict(X_test)

# Métricas
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Confusion Matrix:
#  [[33  0]
#  [ 6 15]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92        33
#            1       1.00      0.71      0.83        21
#
#     accuracy                           0.89        54
#    macro avg       0.92      0.86      0.88        54
# weighted avg       0.91      0.89      0.88        54

# %%
#Curva ROC y AUC Si quieres visualizar la Curva ROC:
from sklearn.metrics import roc_auc_score, roc_curve
import matplotlib.pyplot as plt

y_proba = model.predict_proba(X_test)[:, 1]  # Probabilidad de la clase positiva
fpr, tpr, thresholds = roc_curve(y_test, y_proba)
auc_score = roc_auc_score(y_test, y_proba)

# Gráfica
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f'AUC = {auc_score:.2f}')
plt.plot([0, 1], [0, 1], linestyle='--', color='gray')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.show()
